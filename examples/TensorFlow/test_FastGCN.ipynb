# %%
import tensorflow as tf
import graphgallery 
import matplotlib.pyplot as plt


# Set if memory growth should be enabled for ALL `PhysicalDevice`.
graphgallery.set_memory_growth()
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
tf.__version__
# Out:
# '2.1.2'

# %%
graphgallery.__version__
# Out:
# '0.5.0'

# %% [markdown]
# # Load the Datasets
# + cora
# + citeseer
# + pubmed

# %%
from graphgallery.data import Planetoid

# set `verbose=False` to avoid these printed tables
data = Planetoid('cora', root="~/GraphData/datasets/", verbose=False)
graph = data.graph
idx_train, idx_val, idx_test = data.split_nodes()

# %%
data.supported_datasets
# Out:
# {'citeseer', 'cora', 'pubmed'}

# %%
from graphgallery.nn.gallery import FastGCN
model = FastGCN(graph, device='GPU', attr_transform="normalize_attr", seed=123)
model.build()
# train with validation
his = model.train(idx_train, idx_val, verbose=1, epochs=100)
# train without validation
# his = model.train(idx_train, verbose=1, epochs=100)
loss, accuracy = model.test(idx_test)
print(f'Test loss {loss:.5}, Test accuracy {accuracy:.2%}')
# Out:
# Training...
# 100/100 [==============================] - 2s 20ms/step - loss: 1.0409 - acc: 0.8000 - val_loss: 1.3903 - val_acc: 0.7860 - time: 1.9874
# Testing...
# 1/1 [==============================] - 0s 66ms/step - test_loss: 1.6745 - test_acc: 0.8110 - time: 0.0658
# Test loss 1.6745, Test accuracy 81.10%

# %% [markdown]
# ## Show model summary

# %%
model.summary()
# Out:
# Model: "fast_gcn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attr_matrix (InputLayer)        [(None, 1433)]       0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           45856       attr_matrix[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# adj_matrix (InputLayer)         [(None, None)]       0
# __________________________________________________________________________________________________
# graph_convolution (GraphConvolu (None, 7)            224         dropout[0][0]
#                                                                  adj_matrix[0][0]
# ==================================================================================================
# Total params: 46,080
# Trainable params: 46,080
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Visualization Training

# %%
import matplotlib.pyplot as plt
with plt.style.context(['science', 'no-latex']):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    axes[0].plot(his.history['acc'], label='Train accuracy')
    axes[0].plot(his.history['val_acc'], label='Val accuracy')
    axes[0].legend()
    axes[0].set_title('Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Accuracy')


    axes[1].plot(his.history['loss'], label='Training loss')
    axes[1].plot(his.history['val_loss'], label='Validation loss')
    axes[1].legend()
    axes[1].set_title('Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    
    plt.autoscale(tight=True)
    plt.show()
