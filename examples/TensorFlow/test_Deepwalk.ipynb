# %%
import tensorflow as tf
import graphgallery 
import matplotlib.pyplot as plt


# Set if memory growth should be enabled for ALL `PhysicalDevice`.
graphgallery.set_memory_growth()
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
tf.__version__
# Out:
# '2.1.2'

# %%
graphgallery.__version__
# Out:
# '0.5.0'

# %% [markdown]
# # Load the Datasets
# + cora
# + citeseer
# + pubmed

# %%
from graphgallery.data import Planetoid

# set `verbose=False` to avoid these printed tables
data = Planetoid('cora', root="~/GraphData/datasets/", verbose=False)
graph = data.graph
idx_train, idx_val, idx_test = data.split_nodes()

# %%
data.supported_datasets
# Out:
# {'citeseer', 'cora', 'pubmed'}

# %%
# %%time
from graphgallery.nn.gallery import Deepwalk
model = Deepwalk(graph)
model.build()
model.train(idx_train)
accuracy = model.test(idx_test)
print(f'Test accuracy {accuracy:.2%}')
# Out:
# Test accuracy 69.10%
# CPU times: user 6.45 s, sys: 152 ms, total: 6.6 s
# Wall time: 2.83 s

# %%
embeddings = model.embeddings

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2).fit_transform(embeddings)

# %%
with plt.style.context(['science', 'no-latex']):
    plt.scatter(X_embedded[:,0], X_embedded[:,1], c=graph.labels, cmap=plt.cm.Spectral)
    plt.autoscale(tight=True)
    plt.show()
