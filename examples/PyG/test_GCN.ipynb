# %%
import sys
sys.path.append("../../")
import torch
import torch_geometric
import graphgallery 
import matplotlib.pyplot as plt

# %%
torch.__version__, torch_geometric.__version__
# Out:
# ('1.6.0+cu101', '1.6.1')

# %%
graphgallery.__version__
# Out:
# '0.5.0'

# %% [markdown]
# # Load the Datasets
# + cora
# + citeseer
# + pubmed

# %%
from graphgallery.data import Planetoid

# set `verbose=False` to avoid these printed tables
data = Planetoid('cora', root="~/GraphData/datasets/", verbose=False)
graph = data.graph
idx_train, idx_val, idx_test = data.split_nodes()

# %%
data.supported_datasets
# Out:
# {'citeseer', 'cora', 'pubmed'}

# %%
graphgallery.set_backend("pyg")
# Out:
# PyTorch Geometric 1.6.1 (PyTorch 1.6.0+cu101) Backend

# %%
from graphgallery.nn.gallery import GCN
model = GCN(graph, attr_transform="normalize_attr", device='GPU', seed=123)
model.build()
# train with validation
his = model.train(idx_train, idx_val, verbose=1, epochs=100)
# train without validation
# his = model.train(idx_train, verbose=1, epochs=200)
loss, accuracy = model.test(idx_test)
print(f'Test loss {loss:.5}, Test accuracy {accuracy:.2%}')
# Out:
# Training...
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5325 - acc: 0.9643 - val_loss: 1.0034 - val_acc: 0.7980 - time: 0.3603
# Testing...
# 1/1 [==============================] - 0s 808us/step - test_loss: 0.9733 - test_acc: 0.8130 - time: 8.0010e-04
# Test loss 0.97332, Test accuracy 81.30%

# %% [markdown]
# ## Visualization Training

# %%
import matplotlib.pyplot as plt
with plt.style.context(['science', 'no-latex']):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    axes[0].plot(his.history['acc'], label='Training accuracy')
    axes[0].plot(his.history['val_acc'], label='Validation accuracy')
    axes[0].legend()
    axes[0].set_title('Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Accuracy')


    axes[1].plot(his.history['loss'], label='Training loss')
    axes[1].plot(his.history['val_loss'], label='Validation loss')
    axes[1].legend()
    axes[1].set_title('Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    
    plt.autoscale(tight=True)
    plt.show()
