# %%
import sys
sys.path.append('../')

import tensorflow as tf
import graphgallery 
import matplotlib.pyplot as plt


# Set if memory growth should be enabled for ALL `PhysicalDevice`.
graphgallery.set_memory_growth()
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
tf.__version__
# Out:
# '2.1.0'

# %%
graphgallery.__version__
# Out:
# '0.1.10'

# %% [markdown]
# # Load the Datasets
# + cora
# + citeseer
# + pubmed

# %%
from graphgallery.data import Planetoid

# set `verbose=False` to avoid these printed tables
data = Planetoid('cora', verbose=True)
adj = data.adj
x = data.x
labels = data.labels
idx_train = data.idx_train
idx_val = data.idx_val
idx_test = data.idx_test
# Out:
# Downloaded dataset files have existed.
# +---------------------+--------------------------------------------------------+
# |        File         |                          path                          |
# +=====================+========================================================+
# | ind.cora.x          | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.x                                                  |
# +---------------------+--------------------------------------------------------+
# | ind.cora.tx         | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.tx                                                 |
# +---------------------+--------------------------------------------------------+
# | ind.cora.allx       | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.allx                                               |
# +---------------------+--------------------------------------------------------+
# | ind.cora.y          | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.y                                                  |
# +---------------------+--------------------------------------------------------+
# | ind.cora.ty         | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.ty                                                 |
# +---------------------+--------------------------------------------------------+
# | ind.cora.ally       | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.ally                                               |
# +---------------------+--------------------------------------------------------+
# | ind.cora.graph      | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.graph                                              |
# +---------------------+--------------------------------------------------------+
# | ind.cora.test.index | /home/jtli/Files/Develop/data/planetoid/cora/raw/ind.c |
# |                     | ora.test.index                                         |
# +---------------------+--------------------------------------------------------+
# Processed dataset files have existed.
# +---------------+--------------------------------------------------------------+
# |     File      |                             path                             |
# +===============+==============================================================+
# | adj.pkl       | /home/jtli/Files/Develop/data/planetoid/cora/processed/adj.p |
# |               | kl                                                           |
# +---------------+--------------------------------------------------------------+
# | feature.npy   | /home/jtli/Files/Develop/data/planetoid/cora/processed/featu |
# |               | re.npy                                                       |
# +---------------+--------------------------------------------------------------+
# | label.npy     | /home/jtli/Files/Develop/data/planetoid/cora/processed/label |
# |               | .npy                                                         |
# +---------------+--------------------------------------------------------------+
# | idx_train.npy | /home/jtli/Files/Develop/data/planetoid/cora/processed/idx_t |
# |               | rain.npy                                                     |
# +---------------+--------------------------------------------------------------+
# | idx_val.npy   | /home/jtli/Files/Develop/data/planetoid/cora/processed/idx_v |
# |               | al.npy                                                       |
# +---------------+--------------------------------------------------------------+
# | idx_test.npy  | /home/jtli/Files/Develop/data/planetoid/cora/processed/idx_t |
# |               | est.npy                                                      |
# +---------------+--------------------------------------------------------------+

# %%
data.supported_datasets
# Out:
# ('citeseer', 'cora', 'pubmed')

# %% [markdown]
# # GCN model
# + adj: Scipy sparse matrix
# + x: Numpy array-like matrix
# + labels: Numpy array
# + device: can be "CPU" or "GPU"
# + norm_x: `l1` for row-wise normalize for input `x`

# %%
from graphgallery.nn.models import GCN
model = GCN(adj, x, labels, device='GPU', norm_x='l1', seed=123)
model.build()
# train with validation
his = model.train(idx_train, idx_val, verbose=1, epochs=100)
# train without validation
# his = model.train(idx_train, verbose=1, epochs=100)
loss, accuracy = model.test(idx_test)
print(f'Test loss {loss:.5}, Test accuracy {accuracy:.2%}')
# Out:
# <Loss = 1.0161 Acc = 0.9500 Val_Loss = 1.4101 Val_Acc = 0.7740 >: 100%|██████████| 100/100 [00:01<00:00, 70.24it/s]
# Test loss 1.4123, Test accuracy 81.20%

# %% [markdown]
# ## Show model summary

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# features (InputLayer)           [(None, 1433)]       0
# __________________________________________________________________________________________________
# adj_matrix (InputLayer)         [(None, None)]       0
# __________________________________________________________________________________________________
# graph_convolution (GraphConvolu (None, 16)           22928       features[0][0]
#                                                                  adj_matrix[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16)           0           graph_convolution[0][0]
# __________________________________________________________________________________________________
# graph_convolution_1 (GraphConvo (None, 7)            112         dropout[0][0]
#                                                                  adj_matrix[0][0]
# __________________________________________________________________________________________________
# index (InputLayer)              [(None,)]            0
# __________________________________________________________________________________________________
# gather (Gather)                 (None, 7)            0           graph_convolution_1[0][0]
#                                                                  index[0][0]
# ==================================================================================================
# Total params: 23,040
# Trainable params: 23,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Show parameters

# %%
# show training parameters
model.show('train')
# Out:
# +-------------------+----------------------------+
# |    Parameters     |           Value            |
# +===================+============================+
# | Name              | GCN                        |
# +-------------------+----------------------------+
# | as_model          | False                      |
# +-------------------+----------------------------+
# | callbacks         | None                       |
# +-------------------+----------------------------+
# | early_stop_metric | val_loss                   |
# +-------------------+----------------------------+
# | early_stopping    | None                       |
# +-------------------+----------------------------+
# | epochs            | 100                        |
# +-------------------+----------------------------+
# | kwargs            | {}                         |
# +-------------------+----------------------------+
# | monitor           | val_acc                    |
# +-------------------+----------------------------+
# | save_best         | True                       |
# +-------------------+----------------------------+
# | verbose           | 1                          |
# +-------------------+----------------------------+
# | weight_path       | /tmp/weight/GCN_weights.h5 |
# +-------------------+----------------------------+

# %%
# show model parameters
model.show('model')
# Out:
# +-------------+----------+
# | Parameters  |  Value   |
# +=============+==========+
# | Name        | GCN      |
# +-------------+----------+
# | activations | ['relu'] |
# +-------------+----------+
# | dropouts    | [0.5]    |
# +-------------+----------+
# | hiddens     | [16]     |
# +-------------+----------+
# | l2_norms    | [0.0005] |
# +-------------+----------+
# | lr          | 0.010    |
# +-------------+----------+
# | use_bias    | False    |
# +-------------+----------+

# %%
# By defaule, show all
model.show()
# Out:
# +-------------------+----------------------------+
# |    Parameters     |           Value            |
# +===================+============================+
# | Name              | GCN                        |
# +-------------------+----------------------------+
# | activations       | ['relu']                   |
# +-------------------+----------------------------+
# | as_model          | False                      |
# +-------------------+----------------------------+
# | callbacks         | None                       |
# +-------------------+----------------------------+
# | device            | GPU                        |
# +-------------------+----------------------------+
# | dropouts          | [0.5]                      |
# +-------------------+----------------------------+
# | early_stop_metric | val_loss                   |
# +-------------------+----------------------------+
# | early_stopping    | None                       |
# +-------------------+----------------------------+
# | epochs            | 100                        |
# +-------------------+----------------------------+
# | hiddens           | [16]                       |
# +-------------------+----------------------------+
# | is_adj_sparse     | True                       |
# +-------------------+----------------------------+
# | is_weighted       | False                      |
# +-------------------+----------------------------+
# | is_x_sparse       | False                      |
# +-------------------+----------------------------+
# | kwargs            | {}                         |
# +-------------------+----------------------------+
# | l2_norms          | [0.0005]                   |
# +-------------------+----------------------------+
# | lr                | 0.010                      |
# +-------------------+----------------------------+
# | monitor           | val_acc                    |
# +-------------------+----------------------------+
# | save_best         | True                       |
# +-------------------+----------------------------+
# | seed              | 123                        |
# +-------------------+----------------------------+
# | use_bias          | False                      |
# +-------------------+----------------------------+
# | verbose           | 1                          |
# +-------------------+----------------------------+
# | weight_path       | /tmp/weight/GCN_weights.h5 |
# +-------------------+----------------------------+

# %% [markdown]
# ## Visualization Training

# %%
# NOTE: you must install SciencePlots package for a better preview.
with plt.style.context(['science', 'no-latex']):
    plt.plot(his.history['acc'])
    plt.plot(his.history['val_acc'])
    plt.legend(['Train Accuracy', 'Val Accuracy'])
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.autoscale(tight=True)
    plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
# NOTE: you must install SciencePlots package for a better preview.
with plt.style.context(['science', 'no-latex']):
    plt.plot(his.history['loss'])
    plt.plot(his.history['val_loss'])
    plt.legend(['Train Loss', 'Val Loss'])
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.autoscale(tight=True)
    plt.show()
